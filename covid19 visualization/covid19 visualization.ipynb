# %%
import numpy as np      
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('covid.csv')
df.head(1)
# Out:
#   iso_code location        date  total_cases  new_cases  total_deaths  \
# 0      ABW    Aruba  2020-03-13            2          2             0
#
#    new_deaths  total_cases_per_million  new_cases_per_million  \
# 0           0                   18.733                 18.733
#
#    total_deaths_per_million  new_deaths_per_million  total_tests  new_tests  \
# 0                       0.0                     0.0          NaN        NaN
#
#    total_tests_per_thousand  new_tests_per_thousand tests_units
# 0                       NaN                     NaN         NaN

# %%
cols= ['iso_code','new_cases','new_deaths','total_cases_per_million','new_cases_per_million','total_deaths_per_million',
       'new_deaths_per_million','total_tests','new_tests','total_tests_per_thousand','new_tests_per_thousand','tests_units']
df = df.drop(cols,axis = 1)
df = df.fillna(0)
df = df.query("date == '2020-04-23'")
df = df.sort_values("location", ascending=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(15, 30))

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="total_cases", y="location", data=df,
            label="total_cases", color="c")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(x="total_deaths", y="location", data=df,
            label="total_deaths", color="r")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="upper right", frameon=True)
ax.set(xlim=(0, 12500), ylabel="Country",
       xlabel="Total Cases & Death[SOUTH_KOREA] ")
sns.despine(left=True, bottom=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(15, 30))

# Load the example car crash dataset

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="total_cases", y="location", data=df,
            label="total_cases", color="c")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(x="total_deaths", y="location", data=df,
            label="total_deaths", color="r")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(ylabel="Country", xlabel="Total Cases & Death[WORLD] ")
sns.despine(left=True, bottom=True)
